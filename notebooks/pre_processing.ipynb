# %% [markdown]
# Prompt template

# %% [markdown]
# split construction

# %% [markdown]
# tokenize

# %% [markdown]
# truncation audit

# %% [markdown]
# keep raw gold answers for evaluations

# %% [markdown]
# decode back sanity check
